# %%
from PIL import Image
from IPython.display import display
import math
import cv2
import numpy as np
import glob

# %%
# test

img_size=400

sample_img=Image.open("../dataset_indiv/par1/par1b1_s_001.jpg")
print("original image size: ",sample_img.size)
sample_img_resized = sample_img.resize((img_size,img_size),Image.ANTIALIAS)
print("resized image: ",sample_img_resized.size)
display(sample_img_resized)
sample_img_resized.save("../test_images/image_scaled_single_cell_test.jpg",optimize=True,quality=95)
# Out:
# original image size:  (500, 500)
# resized image:  (400, 400)
# <PIL.Image.Image image mode=L size=400x400 at 0x153FF29C8588>

# %%
# resize the image and save it to another folder

images = glob.glob("../dataset_indiv/par1/*.jpg")
count=1
for image in images:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        re_img=img.resize((img_size,img_size),Image.ANTIALIAS)
#         print(re_img.size)
        path_str="../dataset_indiv_resized/par1/"       
        re_img.save(f'{path_str}/par1_resized_{count}.jpg')
    count=count+1

# %%
images = glob.glob("../dataset_indiv/wt/*.jpg")
count=1
for image in images:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        re_img=img.resize((img_size,img_size),Image.ANTIALIAS)
#         print(re_img.size)
        path_str="../dataset_indiv_resized/wt/"       
        re_img.save(f'{path_str}/wt_resized_{count}.jpg')
    count=count+1

# %%
sample_img=Image.open("../dataset_indiv_resized/par1/par1_resized_2.jpg")
display(sample_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=400x400 at 0x153FF1DB4D30>

# %%
sample_img_rot = sample_img.rotate(45)
display(sample_img_rot)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x153FF1DB4BE0>

# %%
sample_img_rot.size
# Out:
# (400, 400)

# %%
def rot_and_crop_disp(degree, img_size, img):
    img_rot=img.rotate(degree)
    sin_val=math.sin(math.radians(degree))
    cos_val=math.cos(math.radians(degree))
    alpha=img_size*(sin_val*cos_val/(sin_val+cos_val))  # calculated to crop the largest possible area after the rotation
    left=alpha
    upper=alpha
    right=img_size-alpha
    lower=img_size-alpha
    img_crop=img_rot.crop((left,upper,right,lower))
    print("img_rot.size",img_rot.size )
    print("left, upper, right, lower",left,upper,right,lower)
    print("img_crop.size", img_crop.size)
    return display(img_crop)

# %%
img_size=sample_img.size[0]
print("img_size: ",img_size)
# Out:
# img_size:  400

# %%
rot_and_crop_disp(5, img_size, sample_img)
# Out:
# img_rot.size (400, 400)
# left, upper, right, lower 32.05761886844001 32.05761886844001 367.94238113156 367.94238113156
# img_crop.size (336, 336)
# <PIL.Image.Image image mode=L size=336x336 at 0x153FF1DB4400>

# %%
def rot_and_crop_conv(degree, img_size, img):
    img_rot=img.rotate(degree)
    sin_val=math.sin(math.radians(degree))
    cos_val=math.cos(math.radians(degree))
    alpha=img_size*(sin_val*cos_val/(sin_val+cos_val))  # calculated to crop the largest possible area after the rotation
    left=alpha
    upper=alpha
    right=img_size-alpha
    lower=img_size-alpha
    img_crop=img_rot.crop((left,upper,right,lower))
    return img_crop

# %%
images_all = glob.glob("../dataset_indiv_resized/par1/*.jpg")

mult_deg=1
count=1
# rotate from 0 to 5 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 0.5*10 = 5 degree rotation per image
            degree=i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot0to10_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 90 to 95 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   
            degree=90+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot90to100_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 180 to 185 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   
            degree=180+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot180to190_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 270 to 275 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=270+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot270to280_{count}_{i}.jpg')
    count=count+1

# %%
images_all = glob.glob("../dataset_indiv_resized/wt/*.jpg")

mult_deg=1
count=1
# rotate from 0 to 5 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot0to10_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 90 to 95 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=90+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot90to100_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 180 to 185 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=180+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot180to190_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 270 to 275 degrees by 0.5
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=270+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_indiv_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot270to280_{count}_{i}.jpg')
    count=count+1
