# %%
from PIL import Image
from IPython.display import display
import math
import cv2
import numpy as np
import glob

# %%
# test

img_size=400

sample_img=Image.open("../dataset_colony/par1/par1_001.jpg")
print("original image size: ",sample_img.size)
sample_img_resized = sample_img.resize((img_size,img_size),Image.ANTIALIAS)
print("resized image: ",sample_img_resized.size)
display(sample_img_resized)
sample_img_resized.save("../test_images/image_scaled_col_test.jpg",optimize=True,quality=95)
# Out:
# original image size:  (1992, 1536)
# resized image:  (400, 400)
# <PIL.Image.Image image mode=RGB size=400x400 at 0x152CFCF931D0>

# %%
# resize the image and save it to another folder

images = glob.glob("../dataset_colony/par1/*.jpg")
count=1
for image in images:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        re_img=img.resize((img_size,img_size),Image.ANTIALIAS)
#         print(re_img.size)
        path_str="../dataset_colony_resized/par1/"       
        re_img.save(f'{path_str}/par1_resized_{count}.jpg')
    count=count+1

# %%
images = glob.glob("../dataset_colony/wt/*.jpg")
count=1
for image in images:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        re_img=img.resize((img_size,img_size),Image.ANTIALIAS)
#         print(re_img.size)
        path_str="../dataset_colony_resized/wt/"       
        re_img.save(f'{path_str}/wt_resized_{count}.jpg')
    count=count+1

# %%
sample_img=Image.open("../dataset_colony_resized/par1/par1_resized_1.jpg")
display(sample_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x152CFCF87A20>

# %%
sample_img_rot = sample_img.rotate(45)
display(sample_img_rot)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x152CFCF87F98>

# %%
sample_img_rot.size
# Out:
# (400, 400)

# %%
def rot_and_crop_disp(degree, img_size, img):
    img_rot=img.rotate(degree)
    sin_val=math.sin(math.radians(degree))
    cos_val=math.cos(math.radians(degree))
    alpha=img_size*(sin_val*cos_val/(sin_val+cos_val))  # calculated to crop the largest possible area after the rotation
    left=alpha
    upper=alpha
    right=img_size-alpha
    lower=img_size-alpha
    img_crop=img_rot.crop((left,upper,right,lower))
    print("img_rot.size",img_rot.size )
    print("left, upper, right, lower",left,upper,right,lower)
    print("img_crop.size", img_crop.size)
    return display(img_crop)

# %%
img_size=sample_img.size[0]
print("img_size: ",img_size)
# Out:
# img_size:  400

# %%
rot_and_crop_disp(10, img_size, sample_img)
# Out:
# img_rot.size (400, 400)
# left, upper, right, lower 59.047588133138774 59.047588133138774 340.9524118668612 340.9524118668612
# img_crop.size (282, 282)
# <PIL.Image.Image image mode=RGB size=282x282 at 0x152CFCF934A8>

# %%
def rot_and_crop_conv(degree, img_size, img):
    img_rot=img.rotate(degree)
    sin_val=math.sin(math.radians(degree))
    cos_val=math.cos(math.radians(degree))
    alpha=img_size*(sin_val*cos_val/(sin_val+cos_val))  # calculated to crop the largest possible area after the rotation
    left=alpha
    upper=alpha
    right=img_size-alpha
    lower=img_size-alpha
    img_crop=img_rot.crop((left,upper,right,lower))
    return img_crop

# %%
images_all = glob.glob("../dataset_colony_resized/par1/*.jpg")

mult_deg=1
count=1
# rotate from 0 to 10 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot0to10_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 90 to 100 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=90+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot90to100_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 180 to 190 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=180+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot180to190_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 270 to 280 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=270+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/par1/"
            img_conv.save(f'{str_conv}/par1_rot270to280_{count}_{i}.jpg')
    count=count+1

# %%
images_all = glob.glob("../dataset_colony_resized/wt/*.jpg")

mult_deg=1
count=1
# rotate from 0 to 10 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot0to10_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 90 to 100 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=90+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot90to100_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 180 to 190 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=180+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot180to190_{count}_{i}.jpg')
    count=count+1

# %%
count=1
# rotate from 270 to 280 degrees by 1
for image in images_all:     
    with open(image, 'rb') as file:        
        img = Image.open(file)
        for i in range(10):   # then total 1*10 = 10 degree rotation per image
            degree=270+i*mult_deg       
            img_conv = rot_and_crop_conv(degree, img_size, img)
            str_conv = "../dataset_colony_rotated/wt/"
            img_conv.save(f'{str_conv}/wt_rot270to280_{count}_{i}.jpg')
    count=count+1
