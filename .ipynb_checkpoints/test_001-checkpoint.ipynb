# %%
# following codes were tested with Anaconda environment online.

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL

# %%
from time import process_time

# %%
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9559119798468036221
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 182566712618278375
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15851235251826062030
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:1"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15792628383059168774
# physical_device_desc: "device: XLA_GPU device"
# ]

# %%
# tf.test.gpu_device_name()
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:1', device_type='XLA_GPU')]

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.9

# %%
keras.__version__
# Out:
# '2.4.0'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
img_height=400
img_width=518
batch_size=32

# %%
train_ds=tf.keras.preprocessing.image_dataset_from_directory(
    '../data',labels='inferred',label_mode='int',
    validation_split=0.2, subset='training',
    seed=123,color_mode='grayscale',
    image_size=(img_height,img_width),
    batch_size=batch_size
    )
# Out:
# Found 280 files belonging to 2 classes.
# Using 224 files for training.

# %%
val_ds=tf.keras.preprocessing.image_dataset_from_directory(
    '../data',labels='inferred',label_mode='int',
    validation_split=0.2, subset='validation',
    seed=123,color_mode='grayscale',
    image_size=(img_height,img_width),
    batch_size=batch_size
    )
# Out:
# Found 280 files belonging to 2 classes.
# Using 56 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['par1', 'wt']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

for images,labels in train_ds.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis('off')

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 400, 518, 1)
# (32,)

# %%
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. 
# These are two important methods you should use when loading data.

# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch. 
# This will ensure the dataset does not become a bottleneck while training your model. 
# If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk 
# cache.

# Dataset.prefetch() overlaps data preprocessing and model execution while training.

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds=val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# This is for normalization foorr RBG channel. We used Grayscale, so search whether this is required 
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
# Create the model (Note that below model does not contain drop out)

num_classes = 2

# model = Sequential([
#   layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 1)),
#   layers.Conv2D(16, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(32, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(64, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Flatten(),
#   layers.Dense(128, activation='relu'), 
#   layers.Dense(num_classes)
# ])

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 1)),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(256, activation='relu'), #original 128
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_2 (Rescaling)      (None, 400, 518, 1)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 400, 518, 32)      320
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 200, 259, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 200, 259, 64)      18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 100, 129, 64)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 100, 129, 128)     73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 50, 64, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 409600)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               104857856
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 104,951,042
# Trainable params: 104,951,042
# Non-trainable params: 0
# _________________________________________________________________

# %%
t0_start=process_time()

epochs=100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
t0_stop=process_time()
print("Elapsed time: ", t0_stop, t0_start)
print("Time for total "+str(epochs) +" epochs : "+str((t0_stop-t0_start)/600) +" min.")
# Out:
# Epoch 1/100
# 7/7 [==============================] - 17s 2s/step - loss: 5.0810 - accuracy: 0.4911 - val_loss: 0.6805 - val_accuracy: 0.6429
# Epoch 2/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6931 - accuracy: 0.5179 - val_loss: 0.6783 - val_accuracy: 0.6429
# Epoch 3/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6952 - accuracy: 0.5179 - val_loss: 0.7271 - val_accuracy: 0.3571
# Epoch 4/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6814 - accuracy: 0.6295 - val_loss: 0.8282 - val_accuracy: 0.3571
# Epoch 5/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6876 - accuracy: 0.5357 - val_loss: 0.7219 - val_accuracy: 0.3571
# Epoch 6/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6668 - accuracy: 0.5357 - val_loss: 0.8303 - val_accuracy: 0.3571
# Epoch 7/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6568 - accuracy: 0.7054 - val_loss: 0.7736 - val_accuracy: 0.3571
# Epoch 8/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.6036 - accuracy: 0.6250 - val_loss: 0.7061 - val_accuracy: 0.3929
# Epoch 9/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.4994 - accuracy: 0.8482 - val_loss: 0.6157 - val_accuracy: 0.7500
# Epoch 10/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.4222 - accuracy: 0.8527 - val_loss: 0.6063 - val_accuracy: 0.7143
# Epoch 11/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.3718 - accuracy: 0.8571 - val_loss: 0.8419 - val_accuracy: 0.3929
# Epoch 12/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.3247 - accuracy: 0.8661 - val_loss: 0.5787 - val_accuracy: 0.7321
# Epoch 13/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.2066 - accuracy: 0.9241 - val_loss: 0.6898 - val_accuracy: 0.6429
# Epoch 14/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0927 - accuracy: 0.9911 - val_loss: 0.7353 - val_accuracy: 0.6607
# Epoch 15/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.1199 - accuracy: 0.9509 - val_loss: 1.0801 - val_accuracy: 0.5357
# Epoch 16/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.1142 - accuracy: 0.9911 - val_loss: 0.6305 - val_accuracy: 0.6964
# Epoch 17/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.9868 - val_accuracy: 0.6071
# Epoch 18/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0544 - accuracy: 0.9821 - val_loss: 1.0979 - val_accuracy: 0.6964
# Epoch 19/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.0592 - val_accuracy: 0.5893
# Epoch 20/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.7652 - val_accuracy: 0.6607
# Epoch 21/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.9808 - val_accuracy: 0.6071
# Epoch 22/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.8727 - val_accuracy: 0.6786
# Epoch 23/100
# 7/7 [==============================] - 14s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9777 - val_accuracy: 0.6786
# Epoch 24/100
# 7/7 [==============================] - 14s 2s/step - loss: 9.7261e-04 - accuracy: 1.0000 - val_loss: 1.0662 - val_accuracy: 0.6429
# Epoch 25/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.0040e-04 - accuracy: 1.0000 - val_loss: 1.0246 - val_accuracy: 0.6964
# Epoch 26/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.3904e-04 - accuracy: 1.0000 - val_loss: 1.0665 - val_accuracy: 0.6786
# Epoch 27/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.1545e-04 - accuracy: 1.0000 - val_loss: 1.0944 - val_accuracy: 0.6607
# Epoch 28/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.3213e-04 - accuracy: 1.0000 - val_loss: 1.0988 - val_accuracy: 0.6964
# Epoch 29/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.8221e-04 - accuracy: 1.0000 - val_loss: 1.1137 - val_accuracy: 0.6964
# Epoch 30/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.3328e-04 - accuracy: 1.0000 - val_loss: 1.1392 - val_accuracy: 0.6964
# Epoch 31/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.0457e-04 - accuracy: 1.0000 - val_loss: 1.1320 - val_accuracy: 0.6786
# Epoch 32/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.8560e-04 - accuracy: 1.0000 - val_loss: 1.1640 - val_accuracy: 0.6607
# Epoch 33/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.6335e-04 - accuracy: 1.0000 - val_loss: 1.1520 - val_accuracy: 0.6786
# Epoch 34/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.2449e-04 - accuracy: 1.0000 - val_loss: 1.1901 - val_accuracy: 0.6607
# Epoch 35/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.1453e-04 - accuracy: 1.0000 - val_loss: 1.1821 - val_accuracy: 0.6786
# Epoch 36/100
# 7/7 [==============================] - 14s 2s/step - loss: 9.6675e-05 - accuracy: 1.0000 - val_loss: 1.1941 - val_accuracy: 0.6964
# Epoch 37/100
# 7/7 [==============================] - 14s 2s/step - loss: 8.1232e-05 - accuracy: 1.0000 - val_loss: 1.1992 - val_accuracy: 0.6786
# Epoch 38/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.3294e-05 - accuracy: 1.0000 - val_loss: 1.2079 - val_accuracy: 0.6786
# Epoch 39/100
# 7/7 [==============================] - 14s 2s/step - loss: 6.5417e-05 - accuracy: 1.0000 - val_loss: 1.2148 - val_accuracy: 0.6786
# Epoch 40/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.9489e-05 - accuracy: 1.0000 - val_loss: 1.2199 - val_accuracy: 0.6786
# Epoch 41/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.9200e-05 - accuracy: 1.0000 - val_loss: 1.2298 - val_accuracy: 0.6786
# Epoch 42/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.4335e-05 - accuracy: 1.0000 - val_loss: 1.2335 - val_accuracy: 0.6786
# Epoch 43/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.7253e-05 - accuracy: 1.0000 - val_loss: 1.2339 - val_accuracy: 0.6964
# Epoch 44/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.4337e-05 - accuracy: 1.0000 - val_loss: 1.2374 - val_accuracy: 0.6964
# Epoch 45/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.1570e-05 - accuracy: 1.0000 - val_loss: 1.2433 - val_accuracy: 0.6964
# Epoch 46/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.9199e-05 - accuracy: 1.0000 - val_loss: 1.2507 - val_accuracy: 0.6786
# Epoch 47/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.4186e-05 - accuracy: 1.0000 - val_loss: 1.2491 - val_accuracy: 0.6964
# Epoch 48/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.3698e-05 - accuracy: 1.0000 - val_loss: 1.2630 - val_accuracy: 0.6964
# Epoch 49/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.1267e-05 - accuracy: 1.0000 - val_loss: 1.2555 - val_accuracy: 0.6964
# Epoch 50/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.9184e-05 - accuracy: 1.0000 - val_loss: 1.2629 - val_accuracy: 0.6786
# Epoch 51/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.8404e-05 - accuracy: 1.0000 - val_loss: 1.2612 - val_accuracy: 0.6964
# Epoch 52/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.7771e-05 - accuracy: 1.0000 - val_loss: 1.2632 - val_accuracy: 0.6964
# Epoch 53/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.5592e-05 - accuracy: 1.0000 - val_loss: 1.2677 - val_accuracy: 0.6964
# Epoch 54/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.4925e-05 - accuracy: 1.0000 - val_loss: 1.2718 - val_accuracy: 0.6786
# Epoch 55/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.4308e-05 - accuracy: 1.0000 - val_loss: 1.2726 - val_accuracy: 0.6964
# Epoch 56/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.3138e-05 - accuracy: 1.0000 - val_loss: 1.2830 - val_accuracy: 0.6786
# Epoch 57/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.2236e-05 - accuracy: 1.0000 - val_loss: 1.2788 - val_accuracy: 0.6964
# Epoch 58/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.1594e-05 - accuracy: 1.0000 - val_loss: 1.2816 - val_accuracy: 0.6964
# Epoch 59/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.0995e-05 - accuracy: 1.0000 - val_loss: 1.2861 - val_accuracy: 0.6786
# Epoch 60/100
# 7/7 [==============================] - 14s 2s/step - loss: 1.0395e-05 - accuracy: 1.0000 - val_loss: 1.2876 - val_accuracy: 0.6786
# Epoch 61/100
# 7/7 [==============================] - 14s 2s/step - loss: 9.9512e-06 - accuracy: 1.0000 - val_loss: 1.2907 - val_accuracy: 0.6786
# Epoch 62/100
# 7/7 [==============================] - 14s 2s/step - loss: 9.9597e-06 - accuracy: 1.0000 - val_loss: 1.2937 - val_accuracy: 0.6786
# Epoch 63/100
# 7/7 [==============================] - 14s 2s/step - loss: 9.2737e-06 - accuracy: 1.0000 - val_loss: 1.2956 - val_accuracy: 0.6786
# Epoch 64/100
# 7/7 [==============================] - 14s 2s/step - loss: 8.7027e-06 - accuracy: 1.0000 - val_loss: 1.3001 - val_accuracy: 0.6786
# Epoch 65/100
# 7/7 [==============================] - 14s 2s/step - loss: 8.3818e-06 - accuracy: 1.0000 - val_loss: 1.3004 - val_accuracy: 0.6964
# Epoch 66/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.6852e-06 - accuracy: 1.0000 - val_loss: 1.3089 - val_accuracy: 0.6964
# Epoch 67/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.5250e-06 - accuracy: 1.0000 - val_loss: 1.3055 - val_accuracy: 0.6786
# Epoch 68/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.2030e-06 - accuracy: 1.0000 - val_loss: 1.3095 - val_accuracy: 0.6786
# Epoch 69/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.3164e-06 - accuracy: 1.0000 - val_loss: 1.3123 - val_accuracy: 0.6786
# Epoch 70/100
# 7/7 [==============================] - 14s 2s/step - loss: 7.0780e-06 - accuracy: 1.0000 - val_loss: 1.3138 - val_accuracy: 0.6786
# Epoch 71/100
# 7/7 [==============================] - 14s 2s/step - loss: 6.3148e-06 - accuracy: 1.0000 - val_loss: 1.3183 - val_accuracy: 0.6786
# Epoch 72/100
# 7/7 [==============================] - 14s 2s/step - loss: 6.2207e-06 - accuracy: 1.0000 - val_loss: 1.3192 - val_accuracy: 0.6786
# Epoch 73/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.6145e-06 - accuracy: 1.0000 - val_loss: 1.3244 - val_accuracy: 0.6964
# Epoch 74/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.6454e-06 - accuracy: 1.0000 - val_loss: 1.3243 - val_accuracy: 0.6786
# Epoch 75/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.2526e-06 - accuracy: 1.0000 - val_loss: 1.3258 - val_accuracy: 0.6786
# Epoch 76/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.1233e-06 - accuracy: 1.0000 - val_loss: 1.3313 - val_accuracy: 0.6964
# Epoch 77/100
# 7/7 [==============================] - 14s 2s/step - loss: 5.0616e-06 - accuracy: 1.0000 - val_loss: 1.3313 - val_accuracy: 0.6786
# Epoch 78/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.7561e-06 - accuracy: 1.0000 - val_loss: 1.3349 - val_accuracy: 0.6786
# Epoch 79/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.5640e-06 - accuracy: 1.0000 - val_loss: 1.3362 - val_accuracy: 0.6786
# Epoch 80/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.4059e-06 - accuracy: 1.0000 - val_loss: 1.3386 - val_accuracy: 0.6786
# Epoch 81/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.3059e-06 - accuracy: 1.0000 - val_loss: 1.3429 - val_accuracy: 0.7143
# Epoch 82/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.0861e-06 - accuracy: 1.0000 - val_loss: 1.3430 - val_accuracy: 0.6786
# Epoch 83/100
# 7/7 [==============================] - 14s 2s/step - loss: 4.0653e-06 - accuracy: 1.0000 - val_loss: 1.3462 - val_accuracy: 0.6964
# Epoch 84/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.8429e-06 - accuracy: 1.0000 - val_loss: 1.3482 - val_accuracy: 0.6964
# Epoch 85/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.7455e-06 - accuracy: 1.0000 - val_loss: 1.3498 - val_accuracy: 0.6786
# Epoch 86/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.6662e-06 - accuracy: 1.0000 - val_loss: 1.3543 - val_accuracy: 0.6964
# Epoch 87/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.6609e-06 - accuracy: 1.0000 - val_loss: 1.3539 - val_accuracy: 0.6786
# Epoch 88/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.6987e-06 - accuracy: 1.0000 - val_loss: 1.3588 - val_accuracy: 0.7143
# Epoch 89/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.6987e-06 - accuracy: 1.0000 - val_loss: 1.3590 - val_accuracy: 0.6786
# Epoch 90/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.7226e-06 - accuracy: 1.0000 - val_loss: 1.3649 - val_accuracy: 0.7143
# Epoch 91/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.4315e-06 - accuracy: 1.0000 - val_loss: 1.3640 - val_accuracy: 0.6786
# Epoch 92/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.0728e-06 - accuracy: 1.0000 - val_loss: 1.3741 - val_accuracy: 0.7143
# Epoch 93/100
# 7/7 [==============================] - 14s 2s/step - loss: 3.0063e-06 - accuracy: 1.0000 - val_loss: 1.3676 - val_accuracy: 0.6786
# Epoch 94/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.9424e-06 - accuracy: 1.0000 - val_loss: 1.3710 - val_accuracy: 0.6964
# Epoch 95/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.7940e-06 - accuracy: 1.0000 - val_loss: 1.3712 - val_accuracy: 0.6964
# Epoch 96/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.6343e-06 - accuracy: 1.0000 - val_loss: 1.3748 - val_accuracy: 0.6964
# Epoch 97/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.6476e-06 - accuracy: 1.0000 - val_loss: 1.3772 - val_accuracy: 0.6964
# Epoch 98/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.6215e-06 - accuracy: 1.0000 - val_loss: 1.3780 - val_accuracy: 0.6786
# Epoch 99/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.4842e-06 - accuracy: 1.0000 - val_loss: 1.3827 - val_accuracy: 0.6964
# Epoch 100/100
# 7/7 [==============================] - 14s 2s/step - loss: 2.3858e-06 - accuracy: 1.0000 - val_loss: 1.3813 - val_accuracy: 0.6964
# Elapsed time:  19691.141398454 27.815564311
# Time for total 100 epochs : 32.77220972357167 min.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Above graph indicates the sign of overfitting. Let's increase the dataset by augmentation

data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal",
                                                    input_shape=(img_height,img_width,1)),
        layers.experimental.preprocessing.RandomFlip("vertical"),
#         layers.experimental.preprocessing.RandomRotation(0.1, input_shape=(img_height,img_width,1))
        layers.experimental.preprocessing.RandomRotation(0.1)
    ]
)

# %%
plt.figure(figsize=(10,10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax=plt.subplot(3,3,i+1)
        plt.imshow(augmented_images[0].numpy().astype('uint8'))
        plt.axis('off')

# %%
# Also, dropout technique helps reduce overfitting

# model = Sequential([
#     data_augmentation,
#     layers.experimental.preprocessing.Rescaling(1./255),
#     layers.Conv2D(16, 3, padding='same', activation='relu'),
#     layers.MaxPooling2D(),
# #     layers.Dropout(0.5), # newly added
#     layers.Conv2D(32, 3, padding='same', activation='relu'),
#     layers.MaxPooling2D(),
# #     layers.Dropout(0.5), # newly added
#     layers.Conv2D(64, 3, padding='same', activation='relu'),
#     layers.MaxPooling2D(),
#     layers.Dropout(0.2), # so far, 0.3 worked well
#     layers.Flatten(),
#     layers.Dense(64, activation='relu'), # or softmax # decreasing this layer no. causes overfitting?
#     layers.Dense(num_classes)
    
# ])

# test with more filters : 32-64-128
model = Sequential([
    data_augmentation,
    layers.experimental.preprocessing.Rescaling(1./255),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
#     layers.Dropout(0.5), # newly added
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
#     layers.Dropout(0.5), # newly added
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.2), # so far, 0.3 worked well
    layers.Flatten(),
    layers.Dense(512, activation='relu'), # or softmax
    layers.Dense(num_classes)
    
])

# perhaps we need smaller dense layer? (ucohead used 32)

# %%
model.compile(optimizer='adam',
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_2 (Sequential)    (None, 400, 518, 1)       0
# _________________________________________________________________
# rescaling_6 (Rescaling)      (None, 400, 518, 1)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 400, 518, 32)      320
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 200, 259, 32)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 200, 259, 64)      18496
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 100, 129, 64)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 100, 129, 128)     73856
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 50, 64, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50, 64, 128)       0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 409600)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               209715712
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 1026
# =================================================================
# Total params: 209,809,410
# Trainable params: 209,809,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
t1_start=process_time()

epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

t1_stop=process_time()
print("Elapsed time: ", t1_stop, t1_start)
print("Time for total "+str(epochs) +" epochs : "+str((t1_stop-t1_start)/600) +" min.")
# Out:
# Epoch 1/100
# 7/7 [==============================] - 16s 2s/step - loss: 3.7771 - accuracy: 0.4911 - val_loss: 0.9337 - val_accuracy: 0.3571
# Epoch 2/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.7094 - accuracy: 0.4911 - val_loss: 0.7742 - val_accuracy: 0.3571
# Epoch 3/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6953 - accuracy: 0.5000 - val_loss: 0.7348 - val_accuracy: 0.3571
# Epoch 4/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6881 - accuracy: 0.5357 - val_loss: 0.7196 - val_accuracy: 0.3571
# Epoch 5/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6839 - accuracy: 0.5357 - val_loss: 0.7155 - val_accuracy: 0.3571
# Epoch 6/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6905 - accuracy: 0.6250 - val_loss: 0.6911 - val_accuracy: 0.4286
# Epoch 7/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6850 - accuracy: 0.5446 - val_loss: 0.7136 - val_accuracy: 0.3571
# Epoch 8/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6805 - accuracy: 0.5357 - val_loss: 0.7016 - val_accuracy: 0.3571
# Epoch 9/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6732 - accuracy: 0.5357 - val_loss: 0.7033 - val_accuracy: 0.3571
# Epoch 10/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6582 - accuracy: 0.5357 - val_loss: 0.6832 - val_accuracy: 0.4107
# Epoch 11/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6649 - accuracy: 0.5491 - val_loss: 0.6727 - val_accuracy: 0.7857
# Epoch 12/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6614 - accuracy: 0.6339 - val_loss: 0.7455 - val_accuracy: 0.3571
# Epoch 13/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6333 - accuracy: 0.5804 - val_loss: 0.7422 - val_accuracy: 0.3571
# Epoch 14/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.6232 - accuracy: 0.6027 - val_loss: 0.6636 - val_accuracy: 0.5179
# Epoch 15/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5930 - accuracy: 0.6652 - val_loss: 0.6561 - val_accuracy: 0.5357
# Epoch 16/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5800 - accuracy: 0.7009 - val_loss: 0.6808 - val_accuracy: 0.5179
# Epoch 17/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5896 - accuracy: 0.7054 - val_loss: 0.9132 - val_accuracy: 0.4107
# Epoch 18/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.6461 - accuracy: 0.6741 - val_loss: 0.6642 - val_accuracy: 0.5714
# Epoch 19/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5638 - accuracy: 0.7098 - val_loss: 0.6034 - val_accuracy: 0.7857
# Epoch 20/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.5293 - accuracy: 0.7812 - val_loss: 0.5633 - val_accuracy: 0.8214
# Epoch 21/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.5151 - accuracy: 0.7902 - val_loss: 0.5341 - val_accuracy: 0.8036
# Epoch 22/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5061 - accuracy: 0.7812 - val_loss: 0.5075 - val_accuracy: 0.7857
# Epoch 23/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.4882 - accuracy: 0.8036 - val_loss: 0.4753 - val_accuracy: 0.8036
# Epoch 24/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.4609 - accuracy: 0.8170 - val_loss: 0.4090 - val_accuracy: 0.7857
# Epoch 25/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.5318 - accuracy: 0.7188 - val_loss: 0.5820 - val_accuracy: 0.8214
# Epoch 26/100
# 7/7 [==============================] - 16s 2s/step - loss: 0
100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2314 - accuracy: 0.8884 - val_loss: 0.4141 - val_accuracy: 0.8750
# Epoch 88/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.3144 - accuracy: 0.8705 - val_loss: 0.3889 - val_accuracy: 0.8571
# Epoch 89/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.3486 - accuracy: 0.8393 - val_loss: 0.5396 - val_accuracy: 0.8036
# Epoch 90/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.3086 - accuracy: 0.8527 - val_loss: 0.4604 - val_accuracy: 0.8393
# Epoch 91/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2948 - accuracy: 0.8929 - val_loss: 0.3950 - val_accuracy: 0.8750
# Epoch 92/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2661 - accuracy: 0.8973 - val_loss: 0.3075 - val_accuracy: 0.8571
# Epoch 93/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2396 - accuracy: 0.9062 - val_loss: 0.3936 - val_accuracy: 0.8571
# Epoch 94/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2961 - accuracy: 0.8929 - val_loss: 0.3552 - val_accuracy: 0.8571
# Epoch 95/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.2472 - accuracy: 0.9018 - val_loss: 0.4522 - val_accuracy: 0.8571
# Epoch 96/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2304 - accuracy: 0.9152 - val_loss: 0.4136 - val_accuracy: 0.8571
# Epoch 97/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.2305 - accuracy: 0.9062 - val_loss: 0.3152 - val_accuracy: 0.8750
# Epoch 98/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2345 - accuracy: 0.9107 - val_loss: 0.2993 - val_accuracy: 0.8393
# Epoch 99/100
# 7/7 [==============================] - 16s 2s/step - loss: 0.2589 - accuracy: 0.8929 - val_loss: 0.3018 - val_accuracy: 0.8571
# Epoch 100/100
# 7/7 [==============================] - 15s 2s/step - loss: 0.2477 - accuracy: 0.9107 - val_loss: 0.3049 - val_accuracy: 0.8393
# Elapsed time:  67898.081141678 45268.772985257
# Time for total 100 epochs : 37.715513594035016 min.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import pandas as pd
# df = pd.DataFrame(history)
# df.to_csv(index=False)
df = pd.DataFrame(history.history.values())
df
# Out:
#          0         1         2         3         4         5         6   \
# 0  3.777069  0.709351  0.695270  0.688128  0.683889  0.690528  0.684983
# 1  0.491071  0.491071  0.500000  0.535714  0.535714  0.625000  0.544643
# 2  0.933711  0.774179  0.734813  0.719568  0.715483  0.691052  0.713601
# 3  0.357143  0.357143  0.357143  0.357143  0.357143  0.428571  0.357143
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.680464  0.673219  0.658215  ...  0.294844  0.266096  0.239582  0.296110
# 1  0.535714  0.535714  0.535714  ...  0.892857  0.897321  0.906250  0.892857
# 2  0.701598  0.703323  0.683208  ...  0.394962  0.307518  0.393550  0.355175
# 3  0.357143  0.357143  0.410714  ...  0.875000  0.857143  0.857143  0.857143
#
#          94        95        96        97        98        99
# 0  0.247197  0.230372  0.230525  0.234499  0.258938  0.247708
# 1  0.901786  0.915179  0.906250  0.910714  0.892857  0.910714
# 2  0.452221  0.413562  0.315169  0.299307  0.301763  0.304860
# 3  0.857143  0.857143  0.875000  0.839286  0.857143  0.839286
#
# [4 rows x 100 columns]

# %%
df.to_csv('../test05_results.csv')

# %%
img = keras.preprocessing.image.load_img(
#       '../test_images/par1_early_008.jpg',
           '../test_images/par1_late_061.jpg',
#     '../test_images/wt_early_067.jpg', 
#     '../test_images/wt_late_048.jpg', 
    color_mode='grayscale', target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to wt with a 53.59 percent confidence.
