# %%
# following codes were tested with Anaconda environment online.

import matplotlib.pyplot as plt
import numpy as np
import os
import PIL

# %%
from time import process_time

# %%
import tensorflow as tf
# GPU was recognized by installing cudatoolkit :
# conda install cudatoolkit=10.1

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-0ca82b29604d> in <module>
#       1 from tensorflow.python.client import device_lib
# ----> 2 print(device_lib.list_local_devices())
#
# ~/anaconda3/envs/cell/lib/python3.7/site-packages/tensorflow/python/client/device_lib.py in list_local_devices(session_config)
#      41     serialized_config = session_config.SerializeToString()
#      42   return [
# ---> 43       _convert(s) for s in _pywrap_device_lib.list_devices(serialized_config)
#      44   ]
#
# RuntimeError: CUDA runtime implicit initialization on GPU:0 failed. Status: out of memory

# %%
# tf.test.gpu_device_name()
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:1', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.9

# %%
keras.__version__
# Out:
# '2.4.0'

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
img_height=400
img_width=518
batch_size=32

# %%
train_ds=tf.keras.preprocessing.image_dataset_from_directory(
    '../data',labels='inferred',label_mode='int',
    validation_split=0.2, subset='training',
    seed=123,color_mode='grayscale',
    image_size=(img_height,img_width),
    batch_size=batch_size
    )
# Out:
# Found 280 files belonging to 2 classes.
# Using 224 files for training.

# %%
val_ds=tf.keras.preprocessing.image_dataset_from_directory(
    '../data',labels='inferred',label_mode='int',
    validation_split=0.2, subset='validation',
    seed=123,color_mode='grayscale',
    image_size=(img_height,img_width),
    batch_size=batch_size
    )
# Out:
# Found 280 files belonging to 2 classes.
# Using 56 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['par1', 'wt']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))

for images,labels in train_ds.take(1):
    for i in range(9):
        ax=plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis('off')

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 400, 518, 1)
# (32,)

# %%
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. 
# These are two important methods you should use when loading data.

# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch. 
# This will ensure the dataset does not become a bottleneck while training your model. 
# If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk 
# cache.

# Dataset.prefetch() overlaps data preprocessing and model execution while training.

AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds=val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# This is for normalization foorr RBG channel. We used Grayscale, so search whether this is required 
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %%
num_classes = 2

# %%
# Create the model (Note that below model does not contain drop out)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 1)),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(256, activation='relu'), #original 128
#   layers.Dense(512, activation='softmax'), #original 128
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 400, 518, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 400, 518, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 200, 259, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 200, 259, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 129, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 129, 128)     73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 64, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 409600)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               104857856
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 104,951,042
# Trainable params: 104,951,042
# Non-trainable params: 0
# _________________________________________________________________

# %%
# on CPU only : 32 min.
# using GPU : 1 min 18s

t0_start=process_time()

epochs=100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
t0_stop=process_time()
print("Elapsed time: ", t0_stop, t0_start)
print("Time for total "+str(epochs) +" epochs : "+str((t0_stop-t0_start)/600) +" min.")
# Out:
# Epoch 1/100
# 2/7 [=======>......................] - ETA: 0s - loss: 10.5222 - accuracy: 0.4688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0339s vs `on_train_batch_end` time: 0.0688s). Check your callbacks.
# 7/7 [==============================] - 6s 892ms/step - loss: 3.9633 - accuracy: 0.5000 - val_loss: 0.8468 - val_accuracy: 0.3571
# Epoch 2/100
# 7/7 [==============================] - 1s 98ms/step - loss: 0.7528 - accuracy: 0.5357 - val_loss: 0.6992 - val_accuracy: 0.3571
# Epoch 3/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.6827 - accuracy: 0.5357 - val_loss: 0.7417 - val_accuracy: 0.3571
# Epoch 4/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.6775 - accuracy: 0.5714 - val_loss: 0.7247 - val_accuracy: 0.3571
# Epoch 5/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.6604 - accuracy: 0.5357 - val_loss: 0.6883 - val_accuracy: 0.3750
# Epoch 6/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.6373 - accuracy: 0.6562 - val_loss: 0.6934 - val_accuracy: 0.3750
# Epoch 7/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.5779 - accuracy: 0.7054 - val_loss: 0.6110 - val_accuracy: 0.7143
# Epoch 8/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.5326 - accuracy: 0.8080 - val_loss: 0.5496 - val_accuracy: 0.6964
# Epoch 9/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.5049 - accuracy: 0.7098 - val_loss: 0.6208 - val_accuracy: 0.6607
# Epoch 10/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3936 - accuracy: 0.9241 - val_loss: 0.8170 - val_accuracy: 0.4821
# Epoch 11/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.3654 - accuracy: 0.7991 - val_loss: 0.5128 - val_accuracy: 0.7143
# Epoch 12/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2509 - accuracy: 0.9330 - val_loss: 0.4806 - val_accuracy: 0.8214
# Epoch 13/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.2029 - accuracy: 0.9420 - val_loss: 0.6804 - val_accuracy: 0.6429
# Epoch 14/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.1264 - accuracy: 0.9777 - val_loss: 0.6312 - val_accuracy: 0.6607
# Epoch 15/100
# 7/7 [==============================] - 1s 96ms/step - loss: 0.0675 - accuracy: 0.9955 - val_loss: 0.4913 - val_accuracy: 0.7679
# Epoch 16/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.5246 - val_accuracy: 0.7679
# Epoch 17/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 0.8036
# Epoch 18/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.6730 - val_accuracy: 0.6786
# Epoch 19/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.6068 - val_accuracy: 0.7679
# Epoch 20/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6979 - val_accuracy: 0.7857
# Epoch 21/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7359 - val_accuracy: 0.7679
# Epoch 22/100
# 7/7 [==============================] - 1s 97ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7716 - val_accuracy: 0.7679
# Epoch 23/100
# 7/7 [==============================] - 1s 97ms/step - loss: 6.8274e-04 - accuracy: 1.0000 - val_loss: 0.7489 - val_accuracy: 0.8036
# Epoch 24/100
# 7/7 [==============================] - 1s 97ms/step - loss: 5.5769e-04 - accuracy: 1.0000 - val_loss: 0.7664 - val_accuracy: 0.7857
# Epoch 25/100
# 7/7 [==============================] - 1s 97ms/step - loss: 4.7013e-04 - accuracy: 1.0000 - val_loss: 0.7740 - val_accuracy: 0.7857
# Epoch 26/100
# 7/7 [==============================] - 1s 97ms/step - loss: 3.6260e-04 - accuracy: 1.0000 - val_loss: 0.7739 - val_accuracy: 0.7857
# Epoch 27/100
# 7/7 [==============================] - 1s 97ms/step - loss: 2.8625e-04 - accuracy: 1.0000 - val_loss: 0.7964 - val_accuracy: 0.8036
# Epoch 28/100
# 7/7 [==============================] - 1s 97ms/step - loss: 2.7220e-04 - accuracy: 1.0000 - val_loss: 0.7902 - val_accuracy: 0.7857
# Epoch 29/100
# 7/7 [==============================] - 1s 97ms/step - loss: 2.2842e-04 - accuracy: 1.0000 - val_loss: 0.8001 - val_accuracy: 0.7857
# Epoch 30/100
# 7/7 [==============================] - 1s 97ms/step - loss: 2.0649e-04 - accuracy: 1.0000 - val_loss: 0.8118 - val_accuracy: 0.8036
# Epoch 31/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.8546e-04 - accuracy: 1.0000 - val_loss: 0.8130 - val_accuracy: 0.7857
# Epoch 32/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.6419e-04 - accuracy: 1.0000 - val_loss: 0.8199 - val_accuracy: 0.7857
# Epoch 33/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.4978e-04 - accuracy: 1.0000 - val_loss: 0.8233 - val_accuracy: 0.7857
# Epoch 34/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.3435e-04 - accuracy: 1.0000 - val_loss: 0.8367 - val_accuracy: 0.8036
# Epoch 35/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.1998e-04 - accuracy: 1.0000 - val_loss: 0.8347 - val_accuracy: 0.7857
# Epoch 36/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.1370e-04 - accuracy: 1.0000 - val_loss: 0.8471 - val_accuracy: 0.8036
# Epoch 37/100
# 7/7 [==============================] - 1s 97ms/step - loss: 1.0317e-04 - accuracy: 1.0000 - val_loss: 0.8527 - val_accuracy: 0.8036
# Epoch 38/100
# 7/7 [==============================] - 1s 97ms/step - loss: 9.3821e-05 - accuracy: 1.0000 - val_loss: 0.8524 - val_accuracy: 0.8036
# Epoch 39/100
# 7/7 [==============================] - 1s 97ms/step - loss: 8.7258e-05 - accuracy: 1.0000 - val_loss: 0.8666 - val_accuracy: 0.8036
# Epoch 40/100
# 7/7 [==============================] - 1s 97ms/step - loss: 7.7760e-05 - accuracy: 1.0000 - val_loss: 0.8683 - val_accuracy: 0.8036
# Epoch 41/100
# 7/7 [==============================] - 1s 97ms/step - loss: 7.0563e-05 - accuracy: 1.0000 - val_loss: 0.8706 - val_accuracy: 0.8036
# Epoch 42/100
# 7/7 [==============================] - 1s 97ms/step - loss: 6.3897e-05 - accuracy: 1.0000 - val_loss: 0.8810 - val_accuracy: 0.8036
# Epoch 43/100
# 7/7 [==============================] - 1s 97ms/step - loss: 5.9639e-05 - accuracy: 1.0000 - val_loss: 0.8842 - val_accuracy: 0.7857
# Epoch 44/100
# 7/7 [==============================] - 1s 97ms/step - loss: 5.5571e-05 - accuracy: 1.0000 - val_loss: 0.8891 - val_accuracy: 0.7857
# Epoch 45/100
# 7/7 [==============================] - 1s 97ms/step - loss: 5.2253e-05 - accuracy: 1.0000 - val_loss: 0.9037 - val_accuracy: 0.7857
# Epoch 46/100
# 7/7 [==============================] - 1s 97ms/step - loss: 4.6192e-05 - accuracy: 1.0000 - val_loss: 0.9015 - val_accuracy: 0.7857
# Epoch 47/100
# 7/7 [==============================] - 1s 98ms/step - loss: 4.1975e-05 - accuracy: 1.0000 - val_loss: 0.9163 - val_accuracy: 0.7857
# Epoch 48/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.9832e-05 - accuracy: 1.0000 - val_loss: 0.9157 - val_accuracy: 0.7857
# Epoch 49/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.6242e-05 - accuracy: 1.0000 - val_loss: 0.9230 - val_accuracy: 0.7857
# Epoch 50/100
# 7/7 [==============================] - 1s 97ms/step - loss: 3.3013e-05 - accuracy: 1.0000 - val_loss: 0.9365 - val_accuracy: 0.7857
# Epoch 51/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.1669e-05 - accuracy: 1.0000 - val_loss: 0.9331 - val_accuracy: 0.7857
# Epoch 52/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.0493e-05 - accuracy: 1.0000 - val_loss: 0.9473 - val_accuracy: 0.7857
# Epoch 53/100
# 7/7 [==============================] - 1s 97ms/step - loss: 2.6289e-05 - accuracy: 1.0000 - val_loss: 0.9445 - val_accuracy: 0.7857
# Epoch 54/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2
100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.9600e-06 - accuracy: 1.0000 - val_loss: 1.1056 - val_accuracy: 0.7500
# Epoch 81/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.6071e-06 - accuracy: 1.0000 - val_loss: 1.1077 - val_accuracy: 0.7500
# Epoch 82/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.4853e-06 - accuracy: 1.0000 - val_loss: 1.1126 - val_accuracy: 0.7500
# Epoch 83/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.3836e-06 - accuracy: 1.0000 - val_loss: 1.1196 - val_accuracy: 0.7500
# Epoch 84/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.2367e-06 - accuracy: 1.0000 - val_loss: 1.1213 - val_accuracy: 0.7500
# Epoch 85/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.2644e-06 - accuracy: 1.0000 - val_loss: 1.1248 - val_accuracy: 0.7500
# Epoch 86/100
# 7/7 [==============================] - 1s 98ms/step - loss: 3.0281e-06 - accuracy: 1.0000 - val_loss: 1.1297 - val_accuracy: 0.7500
# Epoch 87/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.8051e-06 - accuracy: 1.0000 - val_loss: 1.1320 - val_accuracy: 0.7500
# Epoch 88/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.7136e-06 - accuracy: 1.0000 - val_loss: 1.1370 - val_accuracy: 0.7500
# Epoch 89/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.5736e-06 - accuracy: 1.0000 - val_loss: 1.1394 - val_accuracy: 0.7500
# Epoch 90/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.5534e-06 - accuracy: 1.0000 - val_loss: 1.1438 - val_accuracy: 0.7500
# Epoch 91/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.4390e-06 - accuracy: 1.0000 - val_loss: 1.1468 - val_accuracy: 0.7500
# Epoch 92/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.3129e-06 - accuracy: 1.0000 - val_loss: 1.1499 - val_accuracy: 0.7500
# Epoch 93/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.2208e-06 - accuracy: 1.0000 - val_loss: 1.1555 - val_accuracy: 0.7321
# Epoch 94/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.2134e-06 - accuracy: 1.0000 - val_loss: 1.1566 - val_accuracy: 0.7500
# Epoch 95/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.1388e-06 - accuracy: 1.0000 - val_loss: 1.1606 - val_accuracy: 0.7500
# Epoch 96/100
# 7/7 [==============================] - 1s 98ms/step - loss: 2.0883e-06 - accuracy: 1.0000 - val_loss: 1.1647 - val_accuracy: 0.7500
# Epoch 97/100
# 7/7 [==============================] - 1s 98ms/step - loss: 1.9983e-06 - accuracy: 1.0000 - val_loss: 1.1674 - val_accuracy: 0.7500
# Epoch 98/100
# 7/7 [==============================] - 1s 98ms/step - loss: 1.8882e-06 - accuracy: 1.0000 - val_loss: 1.1799 - val_accuracy: 0.7500
# Epoch 99/100
# 7/7 [==============================] - 1s 98ms/step - loss: 1.7056e-06 - accuracy: 1.0000 - val_loss: 1.1902 - val_accuracy: 0.7321
# Epoch 100/100
# 7/7 [==============================] - 1s 98ms/step - loss: 1.6045e-06 - accuracy: 1.0000 - val_loss: 1.2044 - val_accuracy: 0.7321
# Elapsed time:  106.907605286 27.23107725
# Time for total 100 epochs : 0.13279421339333333 min.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Above graph indicates the sign of overfitting. Let's increase the dataset by augmentation

data_augmentation = keras.Sequential(
    [
        layers.experimental.preprocessing.RandomFlip("horizontal",
                                                    input_shape=(img_height,img_width,1)),
        layers.experimental.preprocessing.RandomFlip("vertical"),
#         layers.experimental.preprocessing.RandomRotation(0.1, input_shape=(img_height,img_width,1))
        layers.experimental.preprocessing.RandomRotation(0.1)
    ]
)

# %%
plt.figure(figsize=(10,10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax=plt.subplot(3,3,i+1)
        plt.imshow(augmented_images[0].numpy().astype('uint8'))
        plt.axis('off')

# %%
# Also, dropout technique helps reduce overfitting

# test with more filters : 32-64-128
model = Sequential([
    data_augmentation,
    layers.experimental.preprocessing.Rescaling(1./255),
#     layers.Conv2D(16, 3, padding='same', activation='relu'), # test09 conv2d 16-32-mp-64-mp-0.2-128-mp-0.2-f-256 *prediction failed
#     layers.Conv2D(32, 3, padding='same', activation='relu'), # test10 conv2d 32-32-mp-64-mp-0.2-128-mp-0.2-f-256 *prediction failed
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
#     layers.Dropout(0.2), # newly added for test07 0.2-0.2-0.2-512
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
#     layers.Dropout(0.2), # newly added for test06 0.2-0.2-512
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.4), # test16:0.4-256-lr0.0005
    layers.Flatten(),
    layers.Dropout(0.4), # test16:0.3-f-0.3-256-lr0.0005
    layers.Dense(256, activation='relu'), # or softmax #test08: 0.2.-0.2-256
    layers.Dropout(0.4), # test16:0.3-f-0.3-256-lr0.0005
#     layers.Dense(512, activation='softmax'), # softmax failed
    layers.Dense(num_classes)
    
])

# perhaps we need smaller dense layer? (ucohead used 32)

# %%
opt=keras.optimizers.Adam(learning_rate=0.001) #default lr=0.001
model.compile(optimizer=opt,
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 400, 518, 1)       0
# _________________________________________________________________
# rescaling_4 (Rescaling)      (None, 400, 518, 1)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 400, 518, 32)      320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 200, 259, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 200, 259, 64)      18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 100, 129, 64)      0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 100, 129, 128)     73856
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 50, 64, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 50, 64, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 409600)            0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 409600)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               104857856
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 104,951,042
# Trainable params: 104,951,042
# Non-trainable params: 0
# _________________________________________________________________

# %%
t1_start=process_time()

epochs = 200 #test11: epoch 200 (0.2.-0.2-256) not saved / test11: 200 for (0.2-256) /test13: 200 for 0.3-256 / test14:lr0.0002
# test15: lr 0.0005 #test17: 0.2-0.2-256-lr0.0002
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

t1_stop=process_time()
print("Elapsed time: ", t1_stop, t1_start)
print("Time for total "+str(epochs) +" epochs : "+str((t1_stop-t1_start)/600) +" min.")
# Out:
# Epoch 1/200
# 2/7 [=======>......................] - ETA: 0s - loss: 4.3578 - accuracy: 0.4375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0376s vs `on_train_batch_end` time: 0.0697s). Check your callbacks.
# 7/7 [==============================] - 1s 119ms/step - loss: 3.6420 - accuracy: 0.4420 - val_loss: 0.6979 - val_accuracy: 0.3571
# Epoch 2/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.6853 - accuracy: 0.5312 - val_loss: 0.7756 - val_accuracy: 0.3571
# Epoch 3/200
# 7/7 [==============================] - 1s 102ms/step - loss: 0.6883 - accuracy: 0.5357 - val_loss: 0.7216 - val_accuracy: 0.3571
# Epoch 4/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.6856 - accuracy: 0.5357 - val_loss: 0.6934 - val_accuracy: 0.3571
# Epoch 5/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.6756 - accuracy: 0.5357 - val_loss: 0.7337 - val_accuracy: 0.3571
# Epoch 6/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.6673 - accuracy: 0.5357 - val_loss: 0.7036 - val_accuracy: 0.3571
# Epoch 7/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.
200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.3152 - accuracy: 0.8661 - val_loss: 0.3977 - val_accuracy: 0.8393
# Epoch 100/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2566 - accuracy: 0.9018 - val_loss: 0.3127 - val_accuracy: 0.9107
# Epoch 101/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2599 - accuracy: 0.9018 - val_loss: 0.3765 - val_accuracy: 0.8393
# Epoch 102/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2499 - accuracy: 0.9107 - val_loss: 0.2994 - val_accuracy: 0.9107
# Epoch 103/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2293 - accuracy: 0.9062 - val_loss: 0.4145 - val_accuracy: 0.8393
# Epoch 104/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2498 - accuracy: 0.8884 - val_loss: 0.2997 - val_accuracy: 0.9107
# Epoch 105/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2429 - accuracy: 0.8884 - val_loss: 0.2516 - val_accuracy: 0.8929
# Epoch 106/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2648 - accuracy: 0.8929 - val_loss: 0.2727 - val_accuracy: 0.8750
# Epoch 107/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2372 - accuracy: 0.9018 - val_loss: 0.2820 - val_accuracy: 0.8929
# Epoch 108/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2497 - accuracy: 0.9062 - val_loss: 0.2768 - val_accuracy: 0.8750
# Epoch 109/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.3016 - accuracy: 0.8482 - val_loss: 0.2814 - val_accuracy: 0.9286
# Epoch 110/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2378 - accuracy: 0.9196 - val_loss: 0.5096 - val_accuracy: 0.8393
# Epoch 111/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2387 - accuracy: 0.9241 - val_loss: 0.3024 - val_accuracy: 0.9107
# Epoch 112/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2031 - accuracy: 0.9241 - val_loss: 0.2810 - val_accuracy: 0.9107
# Epoch 113/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2041 - accuracy: 0.9241 - val_loss: 0.2559 - val_accuracy: 0.9286
# Epoch 114/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2222 - accuracy: 0.9196 - val_loss: 0.2493 - val_accuracy: 0.9107
# Epoch 115/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2599 - accuracy: 0.8884 - val_loss: 0.2892 - val_accuracy: 0.8750
# Epoch 116/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2637 - accuracy: 0.8929 - val_loss: 0.2515 - val_accuracy: 0.8750
# Epoch 117/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.3165 - accuracy: 0.8571 - val_loss: 0.2620 - val_accuracy: 0.8571
# Epoch 118/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2429 - accuracy: 0.9018 - val_loss: 0.5263 - val_accuracy: 0.8036
# Epoch 119/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2371 - accuracy: 0.9152 - val_loss: 0.2904 - val_accuracy: 0.9286
# Epoch 120/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2271 - accuracy: 0.9152 - val_loss: 0.2921 - val_accuracy: 0.9286
# Epoch 121/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2632 - accuracy: 0.9018 - val_loss: 0.4372 - val_accuracy: 0.8571
# Epoch 122/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2930 - accuracy: 0.8839 - val_loss: 0.4040 - val_accuracy: 0.8393
# Epoch 123/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2232 - accuracy: 0.9107 - val_loss: 0.3086 - val_accuracy: 0.9107
# Epoch 124/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2398 - accuracy: 0.9107 - val_loss: 0.3186 - val_accuracy: 0.9286
# Epoch 125/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2059 - accuracy: 0.9241 - val_loss: 0.2454 - val_accuracy: 0.8929
# Epoch 126/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2333 - accuracy: 0.9018 - val_loss: 0.3009 - val_accuracy: 0.8571
# Epoch 127/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.3670 - accuracy: 0.8304 - val_loss: 0.3665 - val_accuracy: 0.8750
# Epoch 128/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.3118 - accuracy: 0.8661 - val_loss: 0.7727 - val_accuracy: 0.7679
# Epoch 129/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.4269 - accuracy: 0.8259 - val_loss: 0.2796 - val_accuracy: 0.9286
# Epoch 130/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.3116 - accuracy: 0.8750 - val_loss: 0.2769 - val_accuracy: 0.9286
# Epoch 131/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2587 - accuracy: 0.9196 - val_loss: 0.4251 - val_accuracy: 0.8571
# Epoch 132/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2454 - accuracy: 0.9152 - val_loss: 0.3126 - val_accuracy: 0.8929
# Epoch 133/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2108 - accuracy: 0.9241 - val_loss: 0.2551 - val_accuracy: 0.8929
# Epoch 134/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2807 - accuracy: 0.8705 - val_loss: 0.2545 - val_accuracy: 0.8929
# Epoch 135/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2745 - accuracy: 0.8750 - val_loss: 0.6565 - val_accuracy: 0.7500
# Epoch 136/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2671 - accuracy: 0.9152 - val_loss: 0.2726 - val_accuracy: 0.9464
# Epoch 137/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1996 - accuracy: 0.9196 - val_loss: 0.2638 - val_accuracy: 0.9286
# Epoch 138/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1823 - accuracy: 0.9509 - val_loss: 0.3617 - val_accuracy: 0.8571
# Epoch 139/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2019 - accuracy: 0.9286 - val_loss: 0.4064 - val_accuracy: 0.8571
# Epoch 140/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2603 - accuracy: 0.8795 - val_loss: 0.2792 - val_accuracy: 0.9464
# Epoch 141/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2478 - accuracy: 0.9018 - val_loss: 0.2678 - val_accuracy: 0.8571
# Epoch 142/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2336 - accuracy: 0.9152 - val_loss: 0.3986 - val_accuracy: 0.8571
# Epoch 143/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1932 - accuracy: 0.9375 - val_loss: 0.3256 - val_accuracy: 0.9286
# Epoch 144/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1832 - accuracy: 0.9286 - val_loss: 0.2516 - val_accuracy: 0.9107
# Epoch 145/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1876 - accuracy: 0.9152 - val_loss: 0.2510 - val_accuracy: 0.9107
# Epoch 146/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2343 - accuracy: 0.8973 - val_loss: 0.2759 - val_accuracy: 0.8750
# Epoch 147/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2200 - accuracy: 0.9152 - val_loss: 0.3418 - val_accuracy: 0.8750
# Epoch 148/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2197 - accuracy: 0.9196 - val_loss: 0.2964 - val_accuracy: 0.9464
# Epoch 149/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1922 - accuracy: 0.9375 - val_loss: 0.2396 - val_accuracy: 0.9286
# Epoch 150/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1427 - accuracy: 0.9643 - val_loss: 0.3773 - val_accuracy: 0.8929
# Epoch 151/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1657 - accuracy: 0.9464 - val_loss: 0.3606 - val_accuracy: 0.8929
# Epoch 152/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2067 - accuracy: 0.9241 - val_loss: 0.4173 - val_accuracy: 0.8750
# Epoch 153/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1877 - accuracy: 0.9286 - val_loss: 0.2536 - val_accuracy: 0.9286
# Epoch 154/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2065 - accuracy: 0.9196 - val_loss: 0.2890 - val_accuracy: 0.9464
# Epoch 155/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2040 - accuracy: 0.9241 - val_loss: 0.2517 - val_accuracy: 0.9464
# Epoch 156/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1678 - accuracy: 0.9509 - val_loss: 0.2935 - val_accuracy: 0.9286
# Epoch 157/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1652 - accuracy: 0.9554 - val_loss: 0.2526 - val_accuracy: 0.9464
# Epoch 158/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1513 - accuracy: 0.9330 - val_loss: 0.2691 - val_accuracy: 0.9286
# Epoch 159/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1564 - accuracy: 0.9375 - val_loss: 0.3171 - val_accuracy: 0.8571
# Epoch 160/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1827 - accuracy: 0.9420 - val_loss: 0.3565 - val_accuracy: 0.8929
# Epoch 161/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1701 - accuracy: 0.9330 - val_loss: 0.4326 - val_accuracy: 0.8571
# Epoch 162/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2257 - accuracy: 0.9107 - val_loss: 0.2868 - val_accuracy: 0.9464
# Epoch 163/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2163 - accuracy: 0.9107 - val_loss: 0.2295 - val_accuracy: 0.8929
# Epoch 164/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1877 - accuracy: 0.9375 - val_loss: 0.3647 - val_accuracy: 0.8750
# Epoch 165/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1535 - accuracy: 0.9643 - val_loss: 0.3071 - val_accuracy: 0.9464
# Epoch 166/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1467 - accuracy: 0.9420 - val_loss: 0.2709 - val_accuracy: 0.9464
# Epoch 167/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1827 - accuracy: 0.9241 - val_loss: 0.3204 - val_accuracy: 0.9286
# Epoch 168/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1908 - accuracy: 0.9330 - val_loss: 0.3993 - val_accuracy: 0.8929
# Epoch 169/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2046 - accuracy: 0.9152 - val_loss: 0.5374 - val_accuracy: 0.8036
# Epoch 170/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1864 - accuracy: 0.9330 - val_loss: 0.2402 - val_accuracy: 0.9464
# Epoch 171/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1584 - accuracy: 0.9420 - val_loss: 0.2321 - val_accuracy: 0.9464
# Epoch 172/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1521 - accuracy: 0.9464 - val_loss: 0.2988 - val_accuracy: 0.9286
# Epoch 173/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1510 - accuracy: 0.9375 - val_loss: 0.2955 - val_accuracy: 0.9286
# Epoch 174/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1719 - accuracy: 0.9241 - val_loss: 0.2473 - val_accuracy: 0.9286
# Epoch 175/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1505 - accuracy: 0.9420 - val_loss: 0.2636 - val_accuracy: 0.9286
# Epoch 176/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.2625 - accuracy: 0.8973 - val_loss: 0.4953 - val_accuracy: 0.8393
# Epoch 177/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2136 - accuracy: 0.9196 - val_loss: 0.3325 - val_accuracy: 0.8929
# Epoch 178/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1455 - accuracy: 0.9598 - val_loss: 0.2296 - val_accuracy: 0.9464
# Epoch 179/200
# 7/7 [==============================] - 1s 105ms/step - loss: 0.1542 - accuracy: 0.9554 - val_loss: 0.2670 - val_accuracy: 0.9286
# Epoch 180/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1540 - accuracy: 0.9554 - val_loss: 0.2283 - val_accuracy: 0.9286
# Epoch 181/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1469 - accuracy: 0.9330 - val_loss: 0.2472 - val_accuracy: 0.8929
# Epoch 182/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2123 - accuracy: 0.9286 - val_loss: 0.3128 - val_accuracy: 0.9464
# Epoch 183/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1956 - accuracy: 0.9286 - val_loss: 0.3930 - val_accuracy: 0.8571
# Epoch 184/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1577 - accuracy: 0.9598 - val_loss: 0.2605 - val_accuracy: 0.8929
# Epoch 185/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2077 - accuracy: 0.9286 - val_loss: 0.2953 - val_accuracy: 0.9286
# Epoch 186/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1504 - accuracy: 0.9509 - val_loss: 0.2657 - val_accuracy: 0.9286
# Epoch 187/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1543 - accuracy: 0.9375 - val_loss: 0.2560 - val_accuracy: 0.8929
# Epoch 188/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2478 - accuracy: 0.8884 - val_loss: 0.2767 - val_accuracy: 0.9464
# Epoch 189/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2202 - accuracy: 0.9152 - val_loss: 0.3796 - val_accuracy: 0.8393
# Epoch 190/200
# 7/7 [==============================] - 1s 103ms/step - loss: 0.1958 - accuracy: 0.9420 - val_loss: 0.2274 - val_accuracy: 0.9464
# Epoch 191/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1604 - accuracy: 0.9554 - val_loss: 0.2190 - val_accuracy: 0.9286
# Epoch 192/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1568 - accuracy: 0.9241 - val_loss: 0.2863 - val_accuracy: 0.9286
# Epoch 193/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1512 - accuracy: 0.9464 - val_loss: 0.3079 - val_accuracy: 0.9286
# Epoch 194/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1576 - accuracy: 0.9420 - val_loss: 0.2537 - val_accuracy: 0.9286
# Epoch 195/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1428 - accuracy: 0.9598 - val_loss: 0.4947 - val_accuracy: 0.8036
# Epoch 196/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2268 - accuracy: 0.9152 - val_loss: 0.7064 - val_accuracy: 0.7857
# Epoch 197/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2342 - accuracy: 0.9062 - val_loss: 0.2857 - val_accuracy: 0.9464
# Epoch 198/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1362 - accuracy: 0.9554 - val_loss: 0.2441 - val_accuracy: 0.9107
# Epoch 199/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.2479 - accuracy: 0.9152 - val_loss: 0.2821 - val_accuracy: 0.9286
# Epoch 200/200
# 7/7 [==============================] - 1s 104ms/step - loss: 0.1991 - accuracy: 0.9375 - val_loss: 0.3369 - val_accuracy: 0.8929
# Elapsed time:  556.482063311 428.618791995
# Time for total 200 epochs : 0.21310545219333343 min.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import pandas as pd
# df = pd.DataFrame(history)
# df.to_csv(index=False)
df = pd.DataFrame(history.history.values())
df
# Out:
#         0         1         2         3         4         5         6    \
# 0  3.642017  0.685334  0.688342  0.685647  0.675600  0.667336  0.651969
# 1  0.441964  0.531250  0.535714  0.535714  0.535714  0.535714  0.535714
# 2  0.697936  0.775585  0.721624  0.693413  0.733729  0.703585  0.701168
# 3  0.357143  0.357143  0.357143  0.357143  0.357143  0.357143  0.357143
#
#         7         8         9    ...       190       191       192       193  \
# 0  0.654993  0.626349  0.621109  ...  0.160376  0.156841  0.151225  0.157550
# 1  0.575893  0.544643  0.566964  ...  0.955357  0.924107  0.946429  0.941964
# 2  0.707964  0.674594  0.674453  ...  0.219043  0.286286  0.307947  0.253654
# 3  0.357143  0.410714  0.446429  ...  0.928571  0.928571  0.928571  0.928571
#
#         194       195       196       197       198       199
# 0  0.142772  0.226794  0.234165  0.136178  0.247891  0.199054
# 1  0.959821  0.915179  0.906250  0.955357  0.915179  0.937500
# 2  0.494744  0.706373  0.285701  0.244077  0.282050  0.336854
# 3  0.803571  0.785714  0.946429  0.910714  0.928571  0.892857
#
# [4 rows x 200 columns]

# %%
df.to_csv('../test23_results.csv') 
#17 for dropout 0.4-0.4 / #18 for dropout 0.3-0.4-0.4 / #19 lr=0.0002/ #20 lr=0.001/#21 0.0007 / #21 0.0009 /#22 0.0009 / #23 0.001

# %%
img = keras.preprocessing.image.load_img(
#       '../test_images/par1_early_008.jpg',
           '../test_images/par1_late_061.jpg',
#     '../test_images/wt_early_067.jpg', 
#     '../test_images/wt_late_048.jpg', 
    color_mode='grayscale', target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely belongs to par1 with a 87.01 percent confidence.
