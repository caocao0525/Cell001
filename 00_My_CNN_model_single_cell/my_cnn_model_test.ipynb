# %% [markdown]
# ## MY CNN model
#
# Test CNN model

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
BATCH_SIZE = 10
# IMG_SIZE = (500,500)
# IMG_W = 500
# IMG_H = 500
IMG_SIZE = (300,300)
IMG_W = 300
IMG_H = 300
# IMG_SIZE = (200,200)
# IMG_W = 200
# IMG_H = 200

# %%
train_dataset = image_dataset_from_directory("../../data_single/data_single_conv_split/train/",
                                            shuffle=True,
                                            batch_size=BATCH_SIZE,
                                            image_size=IMG_SIZE)
# Out:
# Found 569 files belonging to 2 classes.

# %%
validation_dataset = image_dataset_from_directory("../../data_single/data_single_conv_split/val/",
                                                 shuffle=True,
                                                 batch_size=BATCH_SIZE,
                                                 image_size=IMG_SIZE)
# Out:
# Found 100 files belonging to 2 classes.

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['par1', 'wt']

# %%
plt.figure(figsize=(10,10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
val_batches = tf.data.experimental.cardinality(validation_dataset)
test_dataset = validation_dataset.take(val_batches//5)
validation_dataset = validation_dataset.skip(val_batches//5)

# %%
print("Number of validation batches : %d" %tf.data.experimental.cardinality(validation_dataset))
print("Number of test batches : %d" %tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of validation batches : 8
# Number of test batches : 2

# %%
AUTOTUNE =tf.data.experimental.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10,10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        augmented_image = data_augmentation(tf.expand_dims(first_image,0))
        plt.imshow(augmented_image[0]/255)
        plt.axis("off")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout

# %%
rescale = tf.keras.layers.experimental.preprocessing.Rescaling(1./127.5, offset = -1)

# %%
#### initially by me 
#### (500x500, dr=0.2, 20 epochs, val_accuracy: 0.4125)
#### (300x300, dr=0.2, es7 epochs, val_accuracy: 0.5750)
# def my_model(input_shape, drop_rate):
#     model = Sequential([
#         Conv2D(filters=32, input_shape=input_shape, kernel_size=(3,3), activation = 'relu'),
#         Dropout(drop_rate),
#         Conv2D(filters=16, kernel_size=(3,3), activation='relu'),
#         Dropout(drop_rate),
#         Conv2D(filters=8, kernel_size=(3,3), activation='relu'),
#         Dropout(drop_rate),
#         MaxPooling2D(pool_size=(4,4)),
#         BatchNormalization(),
#         Flatten(),
#         Dropout(drop_rate),
#         Dense(units=1024, activation='relu')
# #         Dense(units=1, activation='softmax')
#     ])
#     return model

def my_model(input_shape, drop_rate): # dr0.2/
    model = Sequential([
        Conv2D(filters=32, input_shape=input_shape, kernel_size=(3,3), activation = 'relu'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dropout(drop_rate),
        Dense(units=256, activation='relu'),
        Dropout(drop_rate),
        Dense(units=128, activation='relu')
#         Dense(units=1, activation='softmax')
    ])
    return model

# %%
drop_rate = 0.4 #looks it works better than 0.5

model = my_model(first_image.shape, drop_rate)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 341056)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 341056)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               87310592
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# =================================================================
# Total params: 87,362,880
# Trainable params: 87,362,880
# Non-trainable params: 0
# _________________________________________________________________

# %%
prediction_layer = tf.keras.layers.Dense(1, activation="relu")  
#default -linear, 0.5375
#softmax, 0.4000
#relu, 0.6250

# %%
inputs = tf.keras.Input(shape=(IMG_H, IMG_W, 3))
x = data_augmentation(inputs)
x = rescale(x)
x = model(x)
outputs = prediction_layer(x)
cnn_model = tf.keras.Model(inputs, outputs)

# %%
base_lr = 0.0001
cnn_model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_lr), 
                  loss = tf.keras.losses.BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])

# %%
cnn_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 300, 300, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 300, 300, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 128)               87362880
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 87,363,009
# Trainable params: 87,363,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping

class TrainingCallback(Callback):
    def on_train_begin(self, logs=None):
        print("Starting training ...")
    def on_train_end(self, logs=None):
        print("Finished training!")

early_stopping = EarlyStopping(monitor='val_accuracy', verbose=1, patience=5)

# %%
initial_epochs = 200
loss0, accuracy0 = cnn_model.evaluate(validation_dataset)
# Out:
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6997 - accuracy: 0.6375

# %%
print("initial loss : {:.2f}".format(loss0))
print("initial accuracy : {:.2f}".format(accuracy0))
# Out:
# initial loss : 0.70
# initial accuracy : 0.64

# %%
# history = cnn_model.fit(train_dataset,
#                        epochs=initial_epochs,
#                        validation_data=validation_dataset,
#                        callbacks=[TrainingCallback(), early_stopping])
history = cnn_model.fit(train_dataset,
                       epochs=initial_epochs,
                       validation_data=validation_dataset,
                       callbacks=[TrainingCallback()])
# Out:
# Starting training ...
# Epoch 1/200
# 57/57 [==============================] - 6s 99ms/step - loss: 0.6940 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 2/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 3/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 4/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 5/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 6/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 7/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 8/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 9/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 10/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 11/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 12/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 13/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 14/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 15/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 16/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 17/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 18/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 19/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 20/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 21/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 22/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 23/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 24/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 25/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 26/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 27/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 28/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6935 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 29/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 30/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 31/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 32/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 33/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 34/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 35/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 36/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 37/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 38/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 39/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 40/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 41/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 42/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 43/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 44/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 45/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 46/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 47/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 48/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 49/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 50/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 51/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 52/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 53/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 54/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 55/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 56/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 57/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 58/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 59/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 60/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 61/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 62/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 63/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 64/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 65/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 66/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 67/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 68/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 69/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 70/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 71/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 72/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 73/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 74/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 75/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 76/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 77/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 78/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 79/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 80/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 81/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 82/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 83/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 84/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 85/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 86/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 87/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 88/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 89/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 90/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 91/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 92/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 93/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 94/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 95/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 96/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 97/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 98/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 99/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 100/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 101/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 102/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 103/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 104/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 105/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 106/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 107/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 108/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 109/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 110/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 111/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 112/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 113/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 114/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 115/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 116/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 117/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 118/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 119/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 120/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 121/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 122/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 123/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 124/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 125/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 126/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 127/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 128/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 129/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 130/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 131/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 132/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 133/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 134/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 135/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 136/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 137/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 138/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 139/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 140/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5250
# Epoch 141/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 142/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 143/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 144/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 145/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 146/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 147/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6625
# Epoch 148/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 149/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 150/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 151/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 152/200
# 57/57 [==============================] - 2s 30ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 153/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 154/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 155/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6375
# Epoch 156/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 157/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 158/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5375
# Epoch 159/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 160/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 161/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 162/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 163/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 164/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 165/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 166/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 167/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 168/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 169/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 170/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 171/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6250
# Epoch 172/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 173/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 174/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 175/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 176/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 177/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 178/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 179/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 180/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 181/200
# 57/57 [==============================] - 2s 34ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 182/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 183/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 184/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 185/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6500
# Epoch 186/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 187/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5500
# Epoch 188/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5625
# Epoch 189/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 190/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 191/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 192/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 193/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 194/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6000
# Epoch 195/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 196/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.6125
# Epoch 197/200
# 57/57 [==============================] - 2s 33ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 198/200
# 57/57 [==============================] - 2s 32ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5750
# Epoch 199/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Epoch 200/200
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6931 - accuracy: 0.5255 - val_loss: 0.6931 - val_accuracy: 0.5875
# Finished training!

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# import pickle
# with open("./cnn_model_test00",'wb') as file_pi:
#     pickle.dump(history_fine.history, file_pi)

# %%
# test_load = pickle.load(open("./cnn_model_test00",'rb'))
# test_load['loss']
